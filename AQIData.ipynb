# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeksha0209/AQI-Dataset/blob/main/AQIData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataAQI(AutoRecovered).csv', encoding='cp1252')
# Out:
# <ipython-input-187-f484ea31c7b3>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataAQI(AutoRecovered).csv', encoding='cp1252')

# %%
#displays bottom 5 entries
df.tail()
# Out:
#        stn_code        date        state  location  \
# 435734     SAMP  2015-12-15  West Bengal  ULUBERIA
# 435735     SAMP  2015-12-18  West Bengal  ULUBERIA
# 435736     SAMP  2015-12-21  West Bengal  ULUBERIA
# 435737     SAMP  2015-12-24  West Bengal  ULUBERIA
# 435738     SAMP  2015-12-29  West Bengal  ULUBERIA
#
#                                            agency   type   so2   no2   rspm  \
# 435734  West Bengal State Pollution Control Board  RIRUO  20.0  44.0  148.0
# 435735  West Bengal State Pollution Control Board  RIRUO  17.0  44.0  131.0
# 435736  West Bengal State Pollution Control Board  RIRUO  18.0  45.0  140.0
# 435737  West Bengal State Pollution Control Board  RIRUO  22.0  50.0  143.0
# 435738  West Bengal State Pollution Control Board  RIRUO  20.0  46.0  171.0
#
#         spm        location_monitoring_station  pm2_5  Unnamed: 12  \
# 435734  NaN  Inside Rampal Industries,ULUBERIA    NaN          NaN
# ...

# %%
#display top 5 entries
df.head(5)
# Out:
#   stn_code        date           state   location agency  \
# 0    150.0  1990-02-01  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  1990-02-01  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  1990-02-01  Andhra Pradesh  Hyderabad    NaN
# 3    150.0  1990-03-01  Andhra Pradesh  Hyderabad    NaN
# 4    151.0  1990-03-01  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5  Unnamed: 12  Unnamed: 13
# 0                         NaN    NaN          NaN          NaN
# 1                         NaN    NaN          NaN          NaN
# 2                         NaN    NaN          NaN          NaN
# ...

# %%
#display null values
df.isnull().sum()
# Out:
# stn_code                       144074
# date                                4
# state                               0
# location                            0
# agency                         149478
# type                             5390
# so2                             34643
# no2                             16230
# rspm                            40219
# spm                            237384
# location_monitoring_station     27488
# pm2_5                          426425
# Unnamed: 12                    435739
# Unnamed: 13                    435739
# dtype: int64

# %%
#dropping stn_code column - not really required.
df = df.drop('stn_code', axis=1)

# %%
#Dropping extra empty colms.
df = df.drop('Unnamed: 12', axis=1)

# %%
#Dropping extra colms
df = df.drop('Unnamed: 13', axis=1)

# %%
#This colm has only 9314 entries. rest all null!
df = df.drop('pm2_5', axis=1)

# %%
#Choosing to drop this column for now
df = df.drop('location_monitoring_station', axis=1)

# %%
#dropping 4 rows from date colm having nan values!
df.dropna(subset=['date'], inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# Creating a new column for the year
df['Year'] = df['date'].dt.year

# %%
#display a random sample
df.sample(3)
# Out:
#              date             state  location  \
# 122062 2013-12-17  Himachal Pradesh  Parwanoo
# 178530 1998-10-01    Madhya Pradesh    Bhopal
# 38631  2013-03-06             Assam  Guwahati
#
#                                                    agency  \
# 122062  Himachal Pradesh State Environment Proection &...
# 178530            Madhya Pradesh  Pollution Control Board
# 38631                 Assam State Pollution Control Board
#
#                                       type   so2   no2   rspm    spm  Year
# 122062                     Industrial Area   2.0  14.2   93.0    NaN  2013
# 178530  Residential, Rural and other Areas  19.9  30.2    NaN  352.0  1998
# 38631   Residential, Rural and other Areas   8.0  17.0  143.0    NaN  2013

# %%
#display a list of all columns
df.columns
# Out:
# Index(['date', 'state', 'location', 'agency', 'type', 'so2', 'no2', 'rspm',
#        'spm', 'Year'],
#       dtype='object')

# %%
#lets clean agency col now!
#display the no of unique values
df['agency'].nunique()
# Out:
# 64

# %%
#standardinsing entries
df['agency']=df['agency'].replace('Andhra Pradesh  Pollution Control Board','Andhra Pradesh State Pollution Control Board')
df['agency']=df['agency'].replace('ASPB','Assam State Pollution Control Board')
df['agency']=df['agency'].replace('NEER','National Environmental Engineering Research Institute')
df['agency']=df['agency'].replace('Bihar Pollution Control Board','Bihar State Pollution Control Board')
df['agency']=df['agency'].replace('Bihar Sate Pollution Control Board','Bihar State Pollution Control Board')
df['agency']=df['agency'].replace('Goa Pollution Control Board','Goa State Pollution Control Board')
df['agency']=df['agency'].replace('Gujarat Pollution Control Board','Gujarat State Pollution Control Board')
df['agency']=df['agency'].replace('Gujarat State Pollution Control Board','Gujrat State Pollution Control Board')
df['agency']=df['agency'].replace('Haryana Pollution Control Board','Haryana State Pollution Control Board')
df['agency']=df['agency'].replace('Himachal Pradesh  Pollution Control Boar','Himachal Pradesh State Environment Proection & Pollution Control Board')
df['agency']=df['agency'].replace('Karnataka Pollution Control Board','Karnataka State Pollution Control Board')
df['agency']=df['agency'].replace('Kerala Pollution Control Board','Kerala State Pollution Control Board')
df['agency']=df['agency'].replace('Madhya Pradesh  Pollution Control Board','Madhya Pradesh State Pollution Control Board')
df['agency']=df['agency'].replace('Maharashtra Pollution Control Board','Maharashtra State Pollution Control Board')
df['agency']=df['agency'].replace('VRCE','Visveshwaraya National Institute Of Technology')
df['agency']=df['agency'].replace('Orissa Pollution Control Board','Odisha State Pollution Control Board')
df['agency']=df['agency'].replace('Punjab Pollution Control Board','Punjab State Pollution Control Board')
df['agency']=df['agency'].replace('RJPB','Rajasthan State Pollution Control Board')
df['agency']=df['agency'].replace('RPCB','Rajasthan State Pollution Control Board')
df['agency']=df['agency'].replace('Rajasthan Pollution Control Board','Rajasthan State Pollution Control Board')
df['agency']=df['agency'].replace('TNPC','Tamilnadu State Pollution Control Board')
df['agency']=df['agency'].replace('Tamil Nadu Pollution Control Board','Tamilnadu State Pollution Control Board')
df['agency']=df['agency'].replace('Uttar Pradesh  Pollution Control Board','Uttar Pradesh State Pollution Control Board')
df['agency']=df['agency'].replace('Uttar Pradesh Pollution Control Board','Uttar Pradesh State Pollution Control Board')
df['agency']=df['agency'].replace('UPPB','Uttar Pradesh State Pollution Control Board')
df['agency']=df['agency'].replace('West Bengal Pollution Control Board','West Bengal State Pollution Control Board')

# %%
#lets have a look at the no of null values!
#wow, thats a lot!
df['agency'].isnull().sum()
# Out:
# 149478

# %%
#Substituting na values with correct data
df.loc[df['state'] == 'Andhra Pradesh', 'agency'] = 'Andhra Pradesh State Pollution Control Board'
df.loc[df['state'] == 'Assam', 'agency'] = 'Assam State Pollution Control Board'
df.loc[df['state'] == 'Bihar', 'agency'] = 'Bihar State Pollution Control Board'
df.loc[df['state'] == 'Chandigarh', 'agency'] = 'Chandigarh Pollution Control Committee'
df.loc[df['state'] == 'Chhattisgarh', 'agency'] = 'Chattisgarh Environment Conservation Board'
df.loc[df['state'] == 'Dadra & Nagar Haveli', 'agency'] = 'Daman Diu, Dadra & Nagar Heveli Pollution Control Committee'
df.loc[df['state'] == 'Daman & Diu', 'agency'] = 'Daman Diu, Dadra & Nagar Heveli Pollution Control Committee'
df.loc[df['state'] == 'Goa', 'agency'] = 'Goa State Pollution Control Board'
df.loc[df['state'] == 'Delhi', 'agency'] = 'Central Pollution Control Board'
df.loc[df['state'] == 'Gujarat', 'agency'] = 'Gujrat State Pollution Control Board'
df.loc[df['state'] == 'Haryana', 'agency'] = 'Haryana State Pollution Control Board'
df.loc[df['state'] == 'Himachal', 'agency'] = 'Himachal Pradesh State Environment Proection & Pollution Control Board'
df.loc[df['state'] == 'Himachal Pradesh', 'agency'] = 'Himachal Pradesh State Environment Proection & Pollution Control Board'
df.loc[df['state'] == 'Karnataka', 'agency'] = 'Karnataka State Pollution Control Boardd'
df.loc[df['state'] == 'Jammu & Kashmir', 'agency'] = 'Jammu & Kashmir State Pollution Control Board'
df.loc[df['state'] == 'Jharkhand', 'agency'] = 'Jharkhand State Pollution Control Board'
df.loc[df['state'] == 'Kerala', 'agency'] = 'Kerala State Pollution Control Board'
df.loc[df['state'] == 'Madhya Pradesh', 'agency'] = 'Madhya Pradesh State Pollution Control Board'
df.loc[df['state'] == 'Maharashtra', 'agency'] = 'Maharashtra State Pollution Control Board'
df.loc[df['state'] == 'Manipur', 'agency'] = 'MPCB' #Checked from google - manipur poll control board - mpcb
df.loc[df['state'] == 'Meghalaya', 'agency'] = 'Meghalaya State Pollution Control Board'
df.loc[df['state'] == 'Mizoram', 'agency'] = 'Mizoram State Pollution Control Board'
df.loc[df['state'] == 'Nagaland', 'agency'] = 'Nagaland State Pollution Control Board'
df.loc[df['state'] == 'Odisha', 'agency'] = 'Odisha State Pollution Control Board'
df.loc[df['state'] == 'Puducherry', 'agency'] = 'Puducherry Pollution Conrol Committee'
df.loc[df['state'] == 'Punjab', 'agency'] = 'Punjab State Pollution Control Board'
df.loc[df['state'] == 'Rajasthan', 'agency'] = 'Rajasthan State Pollution Control Board'
df.loc[df['state'] == 'Tamil Nadu', 'agency'] = 'Tamilnadu State Pollution Control Board'
df.loc[df['state'] == 'Uttar Pradesh', 'agency'] = 'Uttar Pradesh State Pollution Control Board'
df.loc[df['state'] == 'West Bengal', 'agency'] = 'West Bengal State Pollution Control Board'
df.loc[df['state'] == 'Uttaranchal', 'agency'] = 'Uttarakhand Environment Protection and Pollution Control Board'

# %%
#lets print the unique values without any na values
unique_values_without_nan = df['agency'].dropna().unique()
print(unique_values_without_nan)
# Out:
# ['Andhra Pradesh State Pollution Control Board'
#  'Arunachal Pradesh State Pollution Control Board'
#  'Assam State Pollution Control Board'
#  'Bihar State Pollution Control Board'
#  'Chandigarh Pollution Control Committee'
#  'Chattisgarh Environment Conservation Board'
#  'Daman Diu, Dadra & Nagar Heveli Pollution Control Committee'
#  'Central Pollution Control Board' 'Goa State Pollution Control Board'
#  'Gujrat State Pollution Control Board'
#  'Haryana State Pollution Control Board'
#  'Himachal Pradesh State Environment Proection & Pollution Control Board'
#  'Jammu & Kashmir State Pollution Control Board'
#  'Jharkhand State Pollution Control Board'
#  'Karnataka State Pollution Control Boardd'
#  'Kerala State Pollution Control Board'
#  'Madhya Pradesh State Pollution Control Board'
#  'Maharashtra State Pollution Control Board' 'MPCB'
#  'Meghalaya State Pollution Control Board'
#  'Mizoram State Pollution Control Board'
#  'Nagaland State Pollution Control Board'
# ...

# %%
#dropping this row bcz of multiple nan values.
index_to_drop = 343638
df = df.drop(index_to_drop)

# %%
#lets move to type colm.
df['type'].mode()
# Out:
# 0    Residential, Rural and other Areas
# Name: type, dtype: object

# %%
#subs na values with mode
df['type'].fillna(df['type'].mode().iloc[0], inplace=True)

# %%
#lets find the mean values for the numerical colms!
df['so2'].mean().round()
# Out:
# 11.0

# %%
df['no2'].mean().round()
# Out:
# 26.0

# %%
df['rspm'].median().round()
# Out:
# 90.0

# %%
df['spm'].mean().round()
# Out:
# 221.0

# %%
#now lets fill na values!
df.so2.fillna(df.so2.mean().round(), inplace=True)
df.no2.fillna(df.no2.mean().round(), inplace=True)
df.rspm.fillna(df.rspm.median().round(), inplace=True)
df.spm.fillna(df.spm.mean().round(), inplace=True)

# %%
#shall we now have a look at our na values?
df.isna().sum()

#yayy! Looks good.
# Out:
# date        0
# state       0
# location    0
# agency      0
# type        0
# so2         0
# no2         0
# rspm        0
# spm         0
# Year        0
# dtype: int64

# %%
#Let's do one final chk on the no of duplicates!
df.duplicated().value_counts()
# Out:
# False    434593
# True       1141
# dtype: int64

# %%
#dropping the duplicate entries.
df = df.drop_duplicates()

# %%
#Rechking the total no of duplicate values. Should be 0 now.
df.duplicated().sum()
# Out:
# 0

# %%
#Resetting index
df.reset_index(drop=True, inplace=True)

# %%
#lets have a look at the data types
df.dtypes
# Out:
# date        datetime64[ns]
# state               object
# location            object
# agency              object
# type                object
# so2                float64
# no2                float64
# rspm               float64
# spm                float64
# Year                 int64
# dtype: object

# %%
#lets now take a look at a random sample
df.sample(3)
# Out:
#              date        state     location  \
# 227764 2011-02-06  Maharashtra  Navi Mumbai
# 40162  2014-03-03        Assam   Bongaigaon
# 28322  2007-09-26        Assam    Dibrugarh
#
#                                            agency  \
# 227764  Maharashtra State Pollution Control Board
# 40162         Assam State Pollution Control Board
# 28322         Assam State Pollution Control Board
#
#                                       type   so2   no2   rspm    spm  Year
# 227764  Residential, Rural and other Areas  13.0  38.0  179.0  221.0  2011
# 40162   Residential, Rural and other Areas   8.0  16.0   45.0  221.0  2014
# 28322               Residential and others   3.8  10.5   32.0   52.0  2007

# %%
#display a stats summary!
df.describe()
# Out:
#                  so2            no2           rspm            spm  \
# count  434593.000000  434593.000000  434593.000000  434593.000000
# mean       10.846420      25.833676     107.154178     220.917876
# std        10.717475      18.151831      71.582157     102.177996
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     202.000000
# 50%         9.000000      22.300000      90.000000     221.000000
# 75%        13.000000      32.000000     135.000000     221.000000
# max       909.000000     876.000000    6307.000000    3380.000000
#
#                 Year
# count  434593.000000
# mean     2009.539995
# std         4.778804
# min      1987.000000
# 25%      2007.000000
# 50%      2010.000000
# 75%      2013.000000
# max      2015.000000

# %%
#the final no of rows & colm after data cleaning.
df.shape
# Out:
# (434593, 10)

# %%
#now i will save this df to csv!
#file_path = 'C:\Users\Deeksha\Desktop\DEEKSHA INTERNSHIP DOCS'
#df.to_csv(file_path, index=False)

df.to_csv('/content/AQIData.csv', index=False)
